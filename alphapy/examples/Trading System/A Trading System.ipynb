# %%
# %matplotlib inline
import pandas as pd
import pyfolio as pf

# %%
pwd
# Out:
# '/Users/markconway/Projects/AlphaPy/alphapy/examples/Trading System'

# %%
cd systems
# Out:
# /Users/markconway/Projects/AlphaPy/alphapy/examples/Trading System/systems

# %%
ls
# Out:
# faang_closer_positions_1d.csv     faang_closer_trades_1d.csv
# faang_closer_returns_1d.csv       faang_closer_transactions_1d.csv

# %%
df = pd.read_csv('faang_closer_returns_1d.csv', index_col='date', squeeze=True)
df.index = pd.to_datetime(df.index, utc=True)

# %%
pf.plot_monthly_returns_heatmap(df)

# %%
pf.plot_drawdown_periods(df, 5)
# Out:
# /Users/markconway/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return getattr(obj, method)(*args, **kwds)

# %%
pf.plot_drawdown_underwater(df)

# %%
pf.plot_returns(df)

# %%
pf.plot_rolling_returns(df)

# %%
pf.plot_annual_returns(df)

# %%
pf.plot_monthly_returns_dist(df)

# %%
pf.show_worst_drawdown_periods(df)
# Out:
# /Users/markconway/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return getattr(obj, method)(*args, **kwds)
# Worst drawdown periods Net drawdown in %  Peak date Valley date Recovery date  \
# 0                                  11.61 2016-10-24  2016-11-14    2017-01-19
# 1                                   7.42 2017-06-08  2017-07-03    2017-07-18
# 2                                   5.04 2017-11-28  2017-12-04           NaT
# 3                                   4.64 2017-07-24  2017-09-25    2017-10-05
# 4                                   3.20 2016-09-07  2016-09-09    2016-09-15
#
# Worst drawdown periods Duration
# 0                            64
# 1                            29
# 2                           NaN
# 3                            54
# 4                             7

# %%
pf.plot_return_quantiles(df)

# %%
pf.plot_rolling_sharpe(df)
